# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 59.7 kB/s eta 0:00:00m eta 0:00:010:00:05m
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (4.15.0)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0
#   Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 KB 87.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: click<9,>=7.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 383.3 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy<3,>=1.23 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (2.2.6)
# Collecting watchdog<7,>=2.1.5
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 KB 501.2 kB/s eta 0:00:00 kB/s eta 0:00:01
# Requirement already satisfied: pyarrow>=7.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (2.32.3)
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (6.33.2)
# Collecting cachetools<7,>=4.0
#   Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: packaging>=20 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (24.1)
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 KB 599.9 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/rgukt/.local/lib/python3.10/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/rgukt/.local/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.27.1 in /home/rgukt/.local/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.4.0)
# Requirement already satisfied: jinja2 in /home/rgukt/.local/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 649.6 kB/s eta 0:00:000:00:01 eta 0:00:01
# Requirement already satisfied: tzdata>=2022.7 in /home/rgukt/.local/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rgukt/.local/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<3,>=1.4.0->streamlit) (2022.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.27->streamlit) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rgukt/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rgukt/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.27->streamlit) (3.3)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rgukt/.local/lib/python3.10/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: referencing>=0.28.4 in /home/rgukt/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/rgukt/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.19.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/rgukt/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/rgukt/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, toml, tenacity, smmap, cachetools, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-6.0.0 cachetools-6.2.4 gitdb-4.0.12 gitpython-3.1.46 pydeck-0.9.1 smmap-5.0.2 streamlit-1.52.2 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0

# %%
import streamlit as st
import numpy as np
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# -----------------------------
# 1. Load Models
# -----------------------------
@st.cache_resource
def load_models():
    embed_model = SentenceTransformer("all-MiniLM-L6-v2")
    llm = pipeline(
        "text-generation",
        model="distilgpt2",
        max_new_tokens=150
    )
    return embed_model, llm

embed_model, llm = load_models()

# -----------------------------
# 2. Knowledge Base (Documents)
# -----------------------------
docs = [
    "LangChain helps developers build applications using large language models.",
    "RAG improves LLM accuracy by retrieving relevant external information.",
    "Sentence embeddings capture semantic meaning of text.",
    "Transformers use attention mechanisms to process language.",
    "Vector databases store embeddings for fast similarity search."
]

doc_embeddings = embed_model.encode(docs)

# -----------------------------
# 3. Retriever Function
# -----------------------------
def retrieve(query, top_k=2):
    query_emb = embed_model.encode([query])[0]
    scores = np.dot(doc_embeddings, query_emb)
    top_indices = np.argsort(scores)[-top_k:][::-1]
    return [docs[i] for i in top_indices]

# -----------------------------
# 4. RAG Response Generator
# -----------------------------
def generate_answer(query):
    retrieved_docs = retrieve(query)
    context = "\n".join(retrieved_docs)

    prompt = f"""
You are an AI assistant.
Answer the question using ONLY the context below.

Context:
{context}

Question:
{query}

Answer:
"""

    response = llm(prompt)[0]["generated_text"]
    return response.split("Answer:")[-1].strip(), retrieved_docs

# -----------------------------
# 5. Streamlit UI
# -----------------------------
st.set_page_config(page_title="RAG Chatbot", page_icon="🤖")

st.title("🤖 RAG Chatbot (GenAI + Deep Learning)")
st.write("Ask questions based on the internal knowledge base.")

user_query = st.text_input("Enter your question:")

if user_query:
    with st.spinner("Thinking..."):
        answer, sources = generate_answer(user_query)

    st.subheader("🧠 Answer")
    st.write(answer)

    st.subheader("📚 Retrieved Context")
    for src in sources:
        st.markdown(f"- {src}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import streamlit as st
#       2 import numpy as np
# ----> 3 from sentence_transformers import SentenceTransformer
#       4 from transformers import pipeline
#       6 # -----------------------------
#       7 # 1. Load Models
#       8 # -----------------------------
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
import tensorflow, keras
print(tensorflow.__file__)
print(keras.__file__)
# Out:
# 2026-01-03 12:02:25.498719: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/rgukt/.local/lib/python3.10/site-packages/tensorflow/__init__.py
# /home/rgukt/.local/lib/python3.10/site-packages/keras/__init__.py

# %%
class ChatbotAgent:
    def __init__ (sel,faq_docs):
        self.rag = SimpleRAG(faq_docs)
    def answer_query(self,user_query):
        cont = self.rag.retrieve(user_query,top_k-1)
        return f"Based on: {cont[0]}"

faq = ["Reset password:Click'Forget Password'","Contact Support:email@company.com"]
bot = ChatbotAgent(faq)
print(bot.answer_query("How do I reset?"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6         return f"Based on: {cont[0]}"
#       8 faq = ["Reset password:Click'Forget Password'","Contact support:email@company.com"]
# ----> 9 bot = ChatbotAgent(faq)
#      10 print(bot.answer_query("How do I reset?"))
#
# Cell In[5], line 3, in ChatbotAgent.__init__(sel, faq_docs)
#       2 def __init__ (sel,faq_docs):
# ----> 3     self.rag = SimpleRAG(faq_docs)
#
# NameError: name 'SimpleRAG' is not defined
