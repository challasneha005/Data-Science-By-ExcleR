# %%
import numpy as np

# %%
#1. Activation functions
def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return x*(1-x)

# %%
#2. Dataset {study_hours,attendance}
X = np.array([
    [0,0],[0,1],[1,0],[1,1]
])

y = np.array([
    [0],[1],[1],[1]])
learning_raate = 0.1
epochs = 5000

hidden_input = np.dot(X,weights_input_hidden)+bias_hidden
hidden_output = 

error = y-final_output

d_output = error

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/rgukt/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/rgukt/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

txt = "The cats are running in the gardens"
tokens = word_tokenize(txt.lower())
stop = set(stopwords.words('english'))
tokens = [t for t in tokens if t not in stop]
lemmatizer = WordNetLemmatizer()
result = [lemmatizer.lemmatize(t) for t in tokens]

# %%
tokens
# Out:
# ['cats', 'running', 'gardens']

# %%
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
result
# Out:
# ['cat', 'running', 'garden']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
txt = "your look look look a  like  hike alike preprocessed text text pre  here"
wordcloud = WordCloud(width = 800,height=400).generate(txt)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

text = "Apple Inc. founded by Steve Jobs in California"
doc = nlp(text)

for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Apple Inc. -> ORG
# Steve Jobs -> PERSON
# California -> GPE

# %%
from gensim.models import Word2Vec

sentences = [['apple', 'is','fruit'],['orange', 'is','fruit']]

model = Word2Vec(sentences,vector_size=100,window = 5,min_count=1,workers=4)

vector = model.wv['apple']
similarity = model.wv.similarity('apple','orange')

# %%
similarity
# Out:
# np.float32(-0.013514926)

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 577.0 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk import bigrams,FreqDist
txt = "the cat sat on the mat"
tokens = txt.split()
bigram_list = list(bigrams(tokens))
feq = FreqDist(bigram_list)

context = ('the',)
following = [w for (c,w) in bigram_list if c== 'the']
following
# Out:
# ['cat', 'mat']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

vocab_size = 100
seq_len = 5

model = Sequential([
    Embedding(vocab_size,128,input_length=seq_len),
    LSTM(256,return_sequences=True),
    LSTM(256),
    Dense(vocab_size,activation='softmax')])
model.compile(loss='categorical_crossentropy')
model.fit(X_train,y_train,epochs=50)
# Out:
# 2026-01-01 16:00:53.488530: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/rgukt/.local/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-01-01 16:01:00.922584: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       7 model = Sequential([
#       8     Embedding(vocab_size,128,input_length=seq_len),
# ...

# %%
from transformers import pipeline

generator= pipeline("text-generation", model="gpt2",max_new_tokens=80, temperature=0.7)
result=generator("Explain ML:")[0]
print(result["generated_text"])
# Out:
# 2026-01-02 11:24:00.689836: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from transformers import pipeline
# ----> 3 generator= pipeline("text-generation", model="gpt2",max_new_tokens=80, temperature=0.7)
#       4 result=generator("Explain ML:")[0]
#       5 print(result["generated_text"])
#
# ...

# %%
summarizer = pipeline(
    "summarization",   # ✅ correct spelling
    model="facebook/bart-large-cnn"
)

text = """In generic drugs continued to play a critical role in the U.S pharmaceutical market by reducing healthcare costs and improving access to essential medicines."""

summary = summarizer(text, max_length=150, min_length=40)

print(summary[0]["summary_text"])

# %%
# Load BERT-based sentiment classifier
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

# Input text
#text = "The movie was very interesting and enjoyable."
text="I absolutely hate this movie. It was boring and a complete waste of time."
# Predict sentiment
result = classifier(text)

print(result)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer
from datasets import load_dataset

dataset = load_dataset("csv", data_files="Complaints.csv")

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

train_data = dataset.map(
    lambda x: tokenizer(x['text'], padding='max_length', truncation=True),
    batched=True
)

model = AutoModelForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=3
)

trainer = Trainer(
    model=model,
    train_dataset=train_data["train"]
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/9 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 13
#       6 tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
#       8 train_data = dataset.map(
#       9     lambda x: tokenizer(x['text'], padding='max_length', truncation=True),
#      10     batched=True
#      11 )
# ---> 13 model = AutoModelForSequenceClassification.from_pretrained(
#      14     'bert-base-uncased',
#      15     num_labels=3
#      16 )
#      18 trainer = Trainer(
#      19     model=model,
# ...
