# %% [markdown]
# ## 1) Central Limit Theorem (CLT)
#
# * The **Central Limit Theorem** states that if we take sufficiently large random samples ($n \geq 30$ is common rule) from any population with finite mean $\mu$ and finite standard deviation $\sigma$, then:
#
#   * The **sampling distribution of the sample mean** $\bar{X}$ will be approximately **normally distributed**.
#   * This holds **regardless of the shape** of the population distribution.
#
# * Properties:
#
#   * Mean of sampling distribution = Mean of the population i.e., $\mu_{\bar{X}} = \mu$
#   * Standard deviation of sampling distribution (Standard Error, SE) =
#
#     $$
#     \sigma_{\bar{X}} = \frac{\sigma}{\sqrt{n}}
#     $$
#
# ---
#
# ## 2) Z-Distribution
#
# * **When used?**
#
#   * When the **population standard deviation ($\sigma$) is known**.
#   * When the sample size is **large (n ≥ 30)**, CLT ensures normality.
#   * Used for **hypothesis testing and confidence intervals** when $\sigma$ is available.
#
# * **Formula (Z-statistic):**
#
#   $$
#   Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
#   $$
#
# ---
#
# ## 3) t-Distribution
#
# * **When used?**
#
#   * When the **population standard deviation ($\sigma$) is unknown**.
#   * We use the **sample standard deviation (s)** as an estimate.
#   * More appropriate when the sample size is **small (n < 30)**.
#   * Becomes close to the normal distribution as $n$ increases (for large n, t ≈ Z).
#
# * **Formula (t-statistic):**
#
#   $$
#   t = \frac{\bar{X} - \mu}{s / \sqrt{n}}
#   $$
#
#   where $s$ = sample standard deviation.
#
# * Degrees of freedom (df):
#
#   $$
#   df = n - 1
#   $$
#
# ---
#
# 📌 **Comparison Table**
#
# | Case                      | Distribution   | Formula                                                     |
# | ------------------------- | -------------- | ----------------------------------------------------------- |
# | $\sigma$ known            | Z-distribution | $\displaystyle Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}$ |
# | $\sigma$ unknown, small n | t-distribution | $\displaystyle t = \frac{\bar{X} - \mu}{s / \sqrt{n}}$      |
# | $\sigma$ unknown, large n | t ≈ Z          | Same as above with $s$                                      |
#
# ---

# %% [markdown]
# ![image.png](attachment:58e91098-2611-454a-ada3-b52324b3a090.png)

# %% [markdown]
# In the above comparison diagram 📊
#
# * **Black curve** → Standard Normal (Z-distribution)
# * **Red dashed curve** → t-distribution with small df (df=5), heavier tails
# * **Blue dashed curve** → t-distribution with larger df (df=30), closer to normal
#
# This shows that as sample size (df) increases, the **t-distribution approaches the normal distribution**.
